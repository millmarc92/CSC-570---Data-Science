# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
M=nx.read_gml("polblogs.gml")

# %%
# create weighted graph from M
G = nx.Graph()
for u,v,data in M.edges_iter(data=True):
    if G.has_edge(u,v):
        G[u][v]['weight'] += 1
    else:
        G.add_edge(u, v, weight=1)

# %% [markdown]
# ### 1.  Create a nice looking graph of the political blog network

# %%
plt.figure(figsize=(40,40))
pos=nx.spring_layout(G, iterations=500, scale=5, k=.3)
nx.draw_networkx_labels(G,pos,fontsize=8)
font = {'fontname'   : 'Helvetica',
            'color'      : 'k',
            'fontweight' : 'bold',
            'fontsize'   : 14}
plt.title("Political Blog Network", font)


nx.draw_networkx_nodes(G,pos,node_color='b',alpha=0.4)
nx.draw_networkx_edges(G,pos,alpha=0.4,node_size=0,width=1,edge_color='k')
plt.axis('off')
plt.show()
# Out:
# C:\Users\millm_000\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1288: UserWarning: findfont: Font family ['Helvetica'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### 2.  What are the 10 most influential blogs?

# %%
centrality=nx.eigenvector_centrality(G)

# %%
blog_list = []
for node in centrality:
    blog_list.append((node,centrality[node]))
    
sorted_blog_list = blog_list.sort(key=lambda x: x[1])

# %%
#Return the top 10
sorted(blog_list, key=lambda x: x[1], reverse=True)[:10]
# Out:
# [('atrios.blogspot.com', 0.1948079793663771),
#  ('dailykos.com', 0.16089740205234834),
#  ('washingtonmonthly.com', 0.14653924259836873),
#  ('digbysblog.blogspot.com', 0.14264369221718326),
#  ('bodyandsoul.typepad.com', 0.14113489174330354),
#  ('liberaloasis.com', 0.1395237157110788),
#  ('tbogg.blogspot.com', 0.1370364169982426),
#  ('corrente.blogspot.com', 0.12941759274096154),
#  ('talkingpointsmemo.com', 0.12700519780790956),
#  ('dneiwert.blogspot.com', 0.12237564692546021)]

# %% [markdown]
# ### 3.  What are the 10 least influential blogs?

# %%
#Return the bottom 10
sorted(blog_list, key=lambda x: x[1], reverse=False)[:10]

# %% [markdown]
# ### 4.  Answer this question for both left wing and right wing blogs seperately.  (Optional 10 Extra Credit Points)
