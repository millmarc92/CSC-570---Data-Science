# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# ### Titanic EDA LAB
# Titanic EDA Lab
#
# For this lab you'll be using the titanic dataset (train.csv).   Your assignment is to create an Exploratory Data Analysis of the Titanic Data.   You may use R or Python to turn in your EDA.
#
# For each variable (except name), you'll need to know at least the following information:
#
# <li> Is the variable categorical or continuous
#
# <li> Are there missing values?
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#
# <li> Histograms describing the distribution of the variable.
#
# <li> EDA should be completed for these fields:  'PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', and 'Embarked'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
# C:\Users\millm_000\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %% [markdown]
# ### Passenger ID
#
# <li> Is the variable categorical or continuous
#     - CATEGORICAL
#
# <li> Are there missing values?
#     -NO MISSING VALUES
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - N/A
#
# <li> Histograms describing the distribution of the variable.

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Survived
#
# <li> Is the variable categorical or continuous
#     - CATEGORICAL
#
# <li> Are there missing values?
#     -NO MISSING VALUES
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     -N/A
# <li> Histograms describing the distribution of the variable.
#     - Genders that Survived

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Genders that Survived

fig, axs = plt.subplots(1,2)
df[df.Sex=='male'].Survived.value_counts().plot(kind='barh',ax=axs[0], title="Male Survivorship")
df[df.Sex=='female'].Survived.value_counts().plot(kind='barh',ax=axs[1], title="Female Survivorship")

# %% [markdown]
# ### PClass
#
# <li> Is the variable categorical or continuous
#     - CATEGORICAL: 1, 2, OR 3
#
# <li> Are there missing values?
#     -NO
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - N/A
#
# <li> Histograms describing the distribution of the variable.
#     - Classes Aboard Ship

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Classes aboard Ship

df.Pclass.value_counts().plot(kind='bar', title="Classes Aboard Ship")

# %% [markdown]
# ### Sex
#
# <li> Is the variable categorical or continuous
#         - CATEGORICAL
#
# <li> Are there missing values?
#         - NO
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#        - N/A
#
# <li> Histograms describing the distribution of the variable.
#     - Genders on Ship

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
#Genders on ship?

df.Sex.value_counts().plot(kind='barh', title="Gender on Ship")

# %% [markdown]
# ### Age
#
# <li> Is the variable categorical or continuous
#     - Continuous
# <li> Are there missing values?
#         - 177 missing values
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - Min: 0.42
#     - Max: 80
#     - Mean: 30 approx.
#     - Std: 14.53
#
# <li> Histograms describing the distribution of the variable.
#     - Survivors by age

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
avgAge = df.Age.mean()
avgAge
# Out:
# 29.69911764705882

# %%
#fill in missing Age values

df.Age = df.Age.fillna(value=avgAge)

# %%
df[df.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.describe()
# Out:
# C:\Users\millm_000\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
#Survivors by age

fig, axs = plt.subplots(1,2)
df[df.Age <18].Survived.value_counts().plot(kind='barh',ax=axs[0], title="Below 18")
df[df.Age >18].Survived.value_counts().plot(kind='barh',ax=axs[1], title="Above 18")

# %% [markdown]
# ### SibSp
#
# <li> Is the variable categorical or continuous
#     - Continuous
#
# <li> Are there missing values?
#      - NO MISSING VALUES
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - Min: 0
#     - Max: 8
#     - Mean: 0.52
#     - Std: 1.10
#
# <li> Histograms describing the distribution of the variable.
#     - SibSp Histogram

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
df.SibSp.value_counts().plot(kind='barh', title="SibSp Histogram")

# %% [markdown]
# ### Parch
#
# <li> Is the variable categorical or continuous
#     - Continuous
#
# <li> Are there missing values?
#     - NO MISSING VALUES
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - Min: 0
#     - Max: 6
#     - Mean: 0.38
#     - Std: 0.81
#
# <li> Histograms describing the distribution of the variable.
#     -
#
# <li> EDA should be completed for these fields:  'PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', and 'Embarked'

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.Parch.value_counts().plot(kind='barh', title="Parch Histogram")

# %% [markdown]
# ### Ticket
#
# <li> Is the variable categorical or continuous
#     - Categorical
#
# <li> Are there missing values?
#     - NO MISSING VALUES
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - N/A
#
# <li> Histograms describing the distribution of the variable.
#     - N/A

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Fare
#
# <li> Is the variable categorical or continuous
#     - Categorical
# <li> Are there missing values?
#     - NO MISSING VALUES
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - Min: 0
#     - Max: 512.33
#     - Mean: 32.2
#     - Std: 49.69
# <li> Histograms describing the distribution of the variable.
#     - Fare Histogram

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# FARE HISTOGRAM

df.Fare.hist(bins=5)

# %% [markdown]
# ### Cabin
#
# <li> Is the variable categorical or continuous
#     - Categorical
#
# <li> Are there missing values?
#     - 687 missing values
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - N/A
#
# <li> Histograms describing the distribution of the variable.
#     - N/A

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %% [markdown]
# ### Embarked
#
# <li> Is the variable categorical or continuous
#     - Categorical
#
# <li> Are there missing values?
#     - 2 missing values
#
# <li> Min, Max, Mean, and Standard Deviation of the continuous variables.
#     - N/A
#
# <li> Histograms describing the distribution of the variable.
#     - Embarked Histogram

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
df.Embarked.value_counts().plot(kind='barh', title="Embarked Histogram")
